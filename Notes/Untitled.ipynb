// %% [markdown]
// # Motoko Zip

// %%
using System;

var ass = 100;
for (int i = 0; i<ass; i++){
    Console.WriteLine("Fuck Terennse");
}
// Out:
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// Fuck Terennse
// ...

// %%
|
